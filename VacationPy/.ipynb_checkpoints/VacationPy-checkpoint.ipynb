# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from gmaps) (8.4.0)
# Collecting ipywidgets>=7.0.0
#   Using cached ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from gmaps) (5.3.0)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /usr/local/Cellar/six/1.16.0_2/lib/python3.10/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (3.0.29)
# Requirement already satisfied: backcall in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (2.12.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: pickleshare in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: appnope in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.1.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (60.10.0)
# Requirement already satisfied: stack-data in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.3.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Collecting jupyterlab-widgets>=1.0.0
#   Using cached jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
# Collecting widgetsnbextension~=3.6.0
#   Using cached widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipywidgets>=7.0.0->gmaps) (6.15.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: packaging in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (23.2.0)
# Requirement already satisfied: nest-asyncio in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: psutil in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.6.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (7.3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (6.4.12)
# Requirement already satisfied: asttokens in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->gmaps) (2.0.5)
# Requirement already satisfied: pure-eval in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.2.2)
# Requirement already satisfied: executing in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.10.0)
# Requirement already satisfied: entrypoints in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (6.5.0)
# Requirement already satisfied: jinja2 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.15.0)
# Requirement already satisfied: nbformat in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (5.4.0)
# Requirement already satisfied: argon2-cffi in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (3.0.9)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.2.2)
# Requirement already satisfied: bleach in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (5.0.0)
# Requirement already satisfied: tinycss2 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.6.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (4.6.0)
# Requirement already satisfied: fastjsonschema in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.15.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.3.2.post1)
# Requirement already satisfied: webencodings in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076111 sha256=38d93e8c4060df77fe52c13006fdb67212205f16b61541b1676002bb7a302f8a
#   Stored in directory: /Users/krishnareddy/Library/Caches/pip/wheels/b3/c2/dc/48b3ef16c2184dae51a003f17eb5d065bbbf1af3437d9f14e3
# Successfully built gmaps
# Installing collected packages: geojson, jupyterlab-widgets, widgetsnbextension, ipywidgets, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0 ipywidgets-7.7.1 jupyterlab-widgets-1.1.1 widgetsnbextension-3.6.1
# WARNING: You are using pip version 22.0.4; however, version 22.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.4.3/libexec/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os

# Import API key
from api_keys import g_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 11>()
#       8 import os
#      10 # Import API key
# ---> 11 from api_keys import g_key
#
# ModuleNotFoundError: No module named 'api_keys'

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
csv_file = os.path.join('..', 'WeatherPy', 'Output', 'city_weather.csv')

city_df = pd.read_csv(csv_file)
city_df

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 gmaps.configure(api_key=g_key)
#
# NameError: name 'gmaps' is not defined

# %%
locations = city_df[["Lat", "Lng"]]
humidity = city_df["Humidity"]

fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False)
heat_layer.max_intensity = 100
heat_layer.point_radius = 5


fig.add_layer(heat_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 locations = city_df[["Lat", "Lng"]]
#       2 humidity = city_df["Humidity"]
#       4 fig = gmaps.figure()
#
# NameError: name 'city_df' is not defined

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_df = city_df[(city_df['Temperature'] >= 75) & (city_df['Temperature'] <= 90)]
ideal_df = ideal_df[ideal_df['Wind Speed'] <= 10]
ideal_df = ideal_df[ideal_df['Clouds'] <= 10]
ideal_df = ideal_df[ideal_df['Humidity'] <= 70]
hotel_df = ideal_df
hotel_df
# Out:
#      City ID         City Country    Lat     Lng  Temperature  Humidity  \
# 8    6355222       Yulara      AU -25.24  130.99        82.40        18
# 12   4036284        Alofi      NU -19.06 -169.92        82.40        65
# 15   2244991  Tambacounda      SN  13.75  -13.76        78.04        39
# 31   1254046         Tura      IN  25.52   90.22        87.40        24
# 53   1185095       Teknāf      BD  20.86   92.31        86.23        57
# 118  1637001         Biak      ID  -0.91  122.88        86.00        60
# 123  2450173    Taoudenni      ML  22.68   -3.98        80.58        14
# 186  1273856      Colgong      IN  25.27   87.22        89.73        21
# 202  1255175       Talāja      IN  21.35   72.05        86.85        35
# 246  1282027         Malé      MV   4.17   73.51        84.36        67
# 253  3703938         Natá      PA   8.33  -80.52        78.01        42
# 257  1636308    Manokwari      ID  -0.87  134.08        83.91        65
# 275  1260716         Pāli      IN  25.77   73.33        88.39        17
# 371  1259460      Pokaran      IN  26.92   71.92        86.54        25
# 382  1272502          Diu      IN  20.71   70.98        84.33        43
# 397  1630639    Pringsewu      ID  -5.36  104.97        88.99        57
# 403  2460954     Araouane      ML  18.90   -3.53        81.70        12
# 415  2456917      Goundam      ML  16.41   -3.67        81.48        19
# 478  1651591       Amahai      ID  -3.33  128.92        86.23        63
# 493  1337617         Muli      MV   2.92   73.57        84.16        68
# 530  1258338    Ratnagiri      IN  16.98   73.30        86.22        52
# 535  1168700       Ormara      PK  25.21   64.64        79.38        68
# 546  2455735      Kangaba      ML  11.93   -8.42        79.79        49
#
#      Clouds  Wind Speed
# 8         9        4.70
# 12        9        5.82
# 15        0        8.12
# 31        0        5.99
# 53        6        3.02
# 118       4        4.63
# 123       0        6.33
# 186       0        1.90
# 202       0        7.45
# 246      10        2.75
# 253       3        9.19
# 257       3        2.53
# 275       0        5.97
# 371       1        8.88
# 382       0        9.78
# 397       6        0.83
# 403       0        5.55
# 415       0        5.19
# 478       2        2.55
# 493      10        3.60
# 530       9        3.71
# 535       0        0.81
# 546      10        3.94

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
#      City ID         City Country    Lat     Lng  Temperature  Humidity  \
# 8    6355222       Yulara      AU -25.24  130.99        82.40        18
# 12   4036284        Alofi      NU -19.06 -169.92        82.40        65
# 15   2244991  Tambacounda      SN  13.75  -13.76        78.04        39
# 31   1254046         Tura      IN  25.52   90.22        87.40        24
# 53   1185095       Teknāf      BD  20.86   92.31        86.23        57
# 118  1637001         Biak      ID  -0.91  122.88        86.00        60
# 123  2450173    Taoudenni      ML  22.68   -3.98        80.58        14
# 186  1273856      Colgong      IN  25.27   87.22        89.73        21
# 202  1255175       Talāja      IN  21.35   72.05        86.85        35
# 246  1282027         Malé      MV   4.17   73.51        84.36        67
# 253  3703938         Natá      PA   8.33  -80.52        78.01        42
# 257  1636308    Manokwari      ID  -0.87  134.08        83.91        65
# 275  1260716         Pāli      IN  25.77   73.33        88.39        17
# 371  1259460      Pokaran      IN  26.92   71.92        86.54        25
# 382  1272502          Diu      IN  20.71   70.98        84.33        43
# 397  1630639    Pringsewu      ID  -5.36  104.97        88.99        57
# 403  2460954     Araouane      ML  18.90   -3.53        81.70        12
# 415  2456917      Goundam      ML  16.41   -3.67        81.48        19
# 478  1651591       Amahai      ID  -3.33  128.92        86.23        63
# 493  1337617         Muli      MV   2.92   73.57        84.16        68
# 530  1258338    Ratnagiri      IN  16.98   73.30        86.22        52
# 535  1168700       Ormara      PK  25.21   64.64        79.38        68
# 546  2455735      Kangaba      ML  11.93   -8.42        79.79        49
#
#      Clouds  Wind Speed Hotel Name
# 8         9        4.70
# 12        9        5.82
# 15        0        8.12
# 31        0        5.99
# 53        6        3.02
# 118       4        4.63
# 123       0        6.33
# 186       0        1.90
# 202       0        7.45
# 246      10        2.75
# 253       3        9.19
# 257       3        2.53
# 275       0        5.97
# 371       1        8.88
# 382       0        9.78
# 397       6        0.83
# 403       0        5.55
# 415       0        5.19
# 478       2        2.55
# 493      10        3.60
# 530       9        3.71
# 535       0        0.81
# 546      10        3.94

# %%
for index, row in hotel_df.iterrows():
    try:
        
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        params = {
        "keyword": "hotel",
        "radius": 5000,
        "key": g_key,
        }


        lat = row['Lat']
        lng = row['Lng']

        params['location'] = f"{lat}, {lng}"

        hotel_data = requests.get(base_url, params=params).json()
        
        hotel_df.loc[index, "Hotel Name"] = hotel_data["results"][0]["name"]
        
    except IndexError:
        
        hotel_df.loc[index, "Hotel Name"] = "NaN"
        
hotel_df
# Out:
#      City ID         City Country    Lat     Lng  Temperature  Humidity  \
# 8    6355222       Yulara      AU -25.24  130.99        82.40        18
# 12   4036284        Alofi      NU -19.06 -169.92        82.40        65
# 15   2244991  Tambacounda      SN  13.75  -13.76        78.04        39
# 31   1254046         Tura      IN  25.52   90.22        87.40        24
# 53   1185095       Teknāf      BD  20.86   92.31        86.23        57
# 118  1637001         Biak      ID  -0.91  122.88        86.00        60
# 123  2450173    Taoudenni      ML  22.68   -3.98        80.58        14
# 186  1273856      Colgong      IN  25.27   87.22        89.73        21
# 202  1255175       Talāja      IN  21.35   72.05        86.85        35
# 246  1282027         Malé      MV   4.17   73.51        84.36        67
# 253  3703938         Natá      PA   8.33  -80.52        78.01        42
# 257  1636308    Manokwari      ID  -0.87  134.08        83.91        65
# 275  1260716         Pāli      IN  25.77   73.33        88.39        17
# 371  1259460      Pokaran      IN  26.92   71.92        86.54        25
# 382  1272502          Diu      IN  20.71   70.98        84.33        43
# 397  1630639    Pringsewu      ID  -5.36  104.97        88.99        57
# 403  2460954     Araouane      ML  18.90   -3.53        81.70        12
# 415  2456917      Goundam      ML  16.41   -3.67        81.48        19
# 478  1651591       Amahai      ID  -3.33  128.92        86.23        63
# 493  1337617         Muli      MV   2.92   73.57        84.16        68
# 530  1258338    Ratnagiri      IN  16.98   73.30        86.22        52
# 535  1168700       Ormara      PK  25.21   64.64        79.38        68
# 546  2455735      Kangaba      ML  11.93   -8.42        79.79        49
#
#      Clouds  Wind Speed                                Hotel Name
# 8         9        4.70  Desert Gardens Hotel - Ayers Rock Resort
# 12        9        5.82                             Taloa Heights
# 15        0        8.12                                       NaN
# 31        0        5.99                         Hotel Polo Orchid
# 53        6        3.02                              Milky Resort
# 118       4        4.63                                       NaN
# 123       0        6.33                                       NaN
# 186       0        1.90                SPOT ON 61925 Hotel Prerna
# 202       0        7.45                         Velvettas Resorts
# 246      10        2.75                           Season Holidays
# 253       3        9.19                                       NaN
# 257       3        2.53                  Swiss Belhotel Manokwari
# 275       0        5.97                     Hotel Shreenath & Bar
# 371       1        8.88       The Fort Pokaran - A Heritage Hotel
# 382       0        9.78            Hotel TGH - The Grand Highness
# 397       6        0.83                  Urban Style by Front One
# 403       0        5.55                                       NaN
# 415       0        5.19                                       NaN
# 478       2        2.55                            Hotel isabella
# 493      10        3.60                  Medhufushi Island Resort
# 530       9        3.71  Kohinoor Samudra Beach Resort, Ratnagiri
# 535       0        0.81                         Zero Point Ormara
# 546      10        3.94                   Hotel Residence KANGABA

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""


# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)
fig

# Display Map
# Out:
# Figure(layout=FigureLayout(height='420px'))
